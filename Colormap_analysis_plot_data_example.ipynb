# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
reldrugs_heatmap_df
# Out:
#                          1FU_clst0_1 1FU_clst0_2 1FU_clst0_3 1FU_clst1_2  \
# Acetylsalicylic acid       -0.211207   -0.220468    1.138951    0.232721
# Amlodipine                  0.208974   -0.243444    1.024296   -0.594226
# Atorvastatin                1.376777    2.222893    2.718759    0.541545
# Calcium, VitD and others   -1.230888    0.243444   -0.130915    1.662376
# Citalopram                 -1.964829   -0.296297   -1.993996    1.515485
# Cyanocobalamin              0.256557   -2.674513   -0.227519   -3.196397
# Donepezil                   4.151374    1.825511    7.590968   -1.662376
# Enalapril                  -0.713603   -0.243444    0.925076     0.52142
# Felodipine                 -0.953658   -3.123025   -0.235811   -1.666722
# Folic acid                  0.027019   -3.721929   -1.172495   -3.568207
# Furosemide                  0.208974   -3.384599   -1.772101   -3.562741
# Galantamine                 0.172724    4.780629    4.448894    4.419675
# ...

# %%
print(drug_vars)
# Out:
# 0         Acetylsalicylic acid
# 1                   Amlodipine
# 2                 Atorvastatin
# 3     Calcium, VitD and others
# 4                   Citalopram
# 5               Cyanocobalamin
# 6                    Donepezil
# 7                    Enalapril
# 8                   Felodipine
# 9                   Folic acid
# 10                  Furosemide
# 11                 Galantamine
# 12        Levothyroxine sodium
# 13                    Losartan
# 14                   Memantine
# 15                   Metformin
# 16                  Metoprolol
# 17                 Mirtazapine
# 18                  Omeprazole
# 19                    Oxazepam
# 20                 Paracetamol
# 21                Rivastigmine
# 22                  Sertraline
# 23                 Simvastatin
# 24                    Warfarin
# 25                   Zopiclone
# dtype: object

# %%
from Colormap_analysis_plot import *
# %run Colormap_analysis_plot.py
# %matplotlib inline

colormap_plot(reldrugs_heatmap_df, drug_vars, N_groups=4, group_names = [], annot_flag = True, thr_flag = True, score_thr = 2, colorbar_flag = True, yticks_flag = True, fig_title = "Follow-up 1", save_flag = False, save_dir = "")

# %%
# %reset
